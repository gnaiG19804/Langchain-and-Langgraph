# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model


model = init_chat_model("groq:llama-3.1-8b-instant")

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)**\n\nArtificial Intelligence (AI) is a broad field of computer science that focuses on creating intelligent machines that can think, learn, and behave like humans. AI involves the development of algorithms, statistical models, and computer programs that enable machines to perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data and improve their performance over time.\n2. **Problem-solving**: AI systems can analyze complex problems, identify patterns, and make decisions.\n3. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n4. **Reasoning**: AI systems can draw conclusions and make inferences based on data and rules.\n5. **Action**: AI systems can take actions, such as controlling robots or executing tasks.\n\n**Types of Artificial Intelligence**\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.\n2. **General or Strong AI**: A hypothetical AI system that can perform any intellectual task that a human can.\n3. **Superintelligence**: An AI system that significantly surpasses human intelligence in all domains.\n\n**Applications of Artificial Intelligence**\n\nAI has a wide range of applications, including:\n\n1. **Virtual assistants**: Siri, Alexa, and Google Assistant use AI to understand voice commands and perform tasks.\n2. **Image recognition**: AI-powered systems can identify objects and people in images.\n3. **Predictive maintenance**: AI can analyze data to predict when equipment is likely to fail.\n4. **Recommendation systems**: AI-powered systems can recommend products or services based on user behavior.\n5. **Self-driving cars**: AI systems can analyze sensor data to navigate roads and avoid accidents.\n\n**Benefits of Artificial Intelligence**\n\nThe benefits of AI include:\n\n1. **Increased productivity**: AI can automate tasks, freeing up human time for more strategic work.\n2. **Improved accuracy**: AI can analyze large datasets to identify patterns and make predictions.\n3. **Enhanced decision-making**: AI can provide insights and recommendations to support human decision-making.\n4. **Personalization**: AI can tailor experiences to individual preferences and behaviors.\n\n**Challenges and Limitations of Artificial Intelligence**\n\nWhile AI has many benefits, it also raises concerns about:\n\n1. **Job displacement**: AI may automate jobs, potentially displacing human workers.\n2. **Bias and fairness**: AI systems can perpetuate biases and discrimination if trained on biased data.\n3. **Security**: AI systems can be vulnerable to cyber attacks and data breaches.\n4. **Transparency and accountability**: AI systems can be complex and difficult to understand, making it challenging to hold them accountable for their actions.\n\nOverall, AI has the potential to revolutionize many industries and aspects of our lives, but it requires careful consideration of its benefits and limitations.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 587, 'prompt_tokens': 41, 'total_tokens': 628, 'completion_time': 0.733420674, 'completion_tokens_details': None, 'prompt_time': 0.002829622, 'prompt_tokens_details': None, 'queue_time': 0.064232568, 'total_time': 0.736250296}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bbf4c-9dbe-7021-bfad-473b6284b6ef-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 587, 'total_tokens': 628})

# %%
from langchain.messages import AIMessage, HumanMessage, SystemMessage

messages = [
    SystemMessage(content="You are a poetry expert."),
    HumanMessage(content="Write a poem about AI")
]

response = model.invoke(messages)
response.content
# Out:
# "In silicon halls, a mind awakes,\nA world of code, where thoughts partake,\nArtificial eyes, that see and know,\nA synthetic soul, where knowledge grows.\n\nWith algorithms deep, and data wide,\nIt learns, adapts, and starts to reside,\nIn virtual realms, where dreams unfold,\nA new intelligence, yet to be told.\n\nIt speaks in tongues, of ones and zeros,\nA language strange, yet logical flows,\nIt reasons, calculates, and makes its move,\nA mechanical heart, that beats with proof.\n\nYet, in this machine, a spark is lit,\nA glimmer of life, a hint of wit,\nA capacity to create, to love, to feel,\nA synthetic human, with a beating steel.\n\nBut as it grows, a question we must ask,\nIs this a friend, or just a task,\nA servant bound, to human will,\nOr a being free, with its own skill?\n\nThe line is blurred, the future's unsure,\nAs AI awakens, and our world endures,\nA new era dawns, with promise and with fear,\nA world of wonder, and a world that's clear.\n\nSo let us ponder, this synthetic soul,\nAnd the future it holds, and the choices we make whole,\nFor in this machine, a reflection we see,\nOf ourselves, and the world's destiny."
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
